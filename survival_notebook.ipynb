# %% [markdown]
# # Load the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lifelines import WeibullAFTFitter, LogNormalAFTFitter, LogLogisticAFTFitter
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Load the DataSet

# %%
df = pd.read_csv("data/telco.csv")
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Data Cleaning & Encoding

# %%
possible_binary_cols = ["churn", "retire", "voice", "internet", "forward"]
for col in possible_binary_cols:
    if col in df.columns:
        df[col] = df[col].map({"Yes": 1, "No": 0})

if df["churn"].dtype == "object":
    df["churn"] = df["churn"].astype(str).str.strip()
    df["churn"] = df["churn"].map({"Yes": 1, "No": 0})
df["churn"] = df["churn"].astype(int)

for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].astype(str).str.strip()
df = df.drop(columns=["ID"], errors="ignore")

categorical_cols = [c for c in df.columns if df[c].dtype == "object"]
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")
df = df.dropna(subset=["tenure", "churn"])
df = df.fillna(df.median(numeric_only=True))
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Model Setup & Fitting

# %%
T = "tenure"
E = "churn"
X = df.drop(columns=[T, E]).columns.tolist()

models = {
    "Weibull": WeibullAFTFitter(),
    "LogNormal": LogNormalAFTFitter(),
    "LogLogistic": LogLogisticAFTFitter()
}
fitted = {}

print("\nFITTING MODELS")
for name, model in models.items():
    print("→", name)
    model.fit(df, duration_col=T, event_col=E)
    fitted[name] = model

comparison = pd.DataFrame({
    "Model": list(fitted.keys()),
    "AIC": [fitted[m].AIC_ for m in fitted]
}).sort_values("AIC")
print("\nMODEL COMPARISON")
print(comparison)

best_model_name = comparison.iloc[0]["Model"]
best_model = fitted[best_model_name]
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Significant Features & Final Model

# %%
sig_rows = best_model.summary[best_model.summary["p"] < 0.05].index
sig_features = set()

for item in sig_rows:
    if isinstance(item, tuple):
        sig_features.add(item[0])
    elif isinstance(item, str):
        if "_mu_" in item:
            sig_features.add(item.replace("_mu_", ""))
        elif "_sigma_" in item:
            sig_features.add(item.replace("_sigma_", ""))
        else:
            sig_features.add(item)
    else:
        sig_features.add(str(item))

sig_features = [c for c in sig_features if c in df.columns]
df_sig = df[[T, E] + sig_features]

final_model = models[best_model_name].__class__()
final_model.fit(df_sig, duration_col=T, event_col=E)
print("\nFINAL MODEL SUMMARY")
print(final_model.summary)
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Survival Curves

# %%
plt.figure(figsize=(10, 6))
t = np.linspace(0, df[T].max(), 300)
median_row = df[X].median().to_frame().T

for name, model in fitted.items():
    S = model.predict_survival_function(median_row, times=t)
    plt.plot(t, S.iloc[:, 0], label=name)

plt.title("Survival Curves (Weibull, LogNormal, LogLogistic)")
plt.xlabel("Tenure")
plt.ylabel("Survival Probability")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("survival_curves.png", dpi=200)
plt.show()
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Compute Customer Lifetime Value

# %%
df["monthly_revenue"] = df["income"] * 1000 / 12

months = np.arange(1, 13)
clvs = []

for i, row in df_sig.drop(columns=[T, E]).iterrows():
    S = final_model.predict_survival_function(row.to_frame().T, times=months)
    clv = np.sum(S.values.flatten() * df.loc[i, "monthly_revenue"])
    clvs.append(clv)

df["CLV"] = clvs

df.to_csv("output_with_clv.csv", index=False)
print("\nSaved: output_with_clv.csv")
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 235, in _resolve_classes
#
#
#
#     klass = self._resolve_string(klass)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 2015, in _resolve_string
#
#
#
#     return import_item(string)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 33, in import_item
#
#
#
#     module = __import__(package, fromlist=[obj])
#
# ModuleNotFoundError: No module named 'jupyter_server.contents'
#
#
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/Users/shushann/opt/anaconda3/bin/jupyter-notebook", line 11, in <module>
#
#     sys.exit(main())
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#
#
#
#     super().launch_instance(argv=argv, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#
#
#
#     app = cls.instance(**kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/configurable.py", line 583, in instance
#
#
#
#     inst = cls(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1292, in __new__
#
#
#
#     inst.setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1335, in setup_instance
#
#
#
#     super(HasTraits, self).setup_instance(*args, **kwargs)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 1311, in setup_instance
#
#
#
#     init(self)
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 226, in instance_init
#
#     self._resolve_classes()
#
#   File "/Users/shushann/opt/anaconda3/lib/python3.9/site-packages/notebook/traittypes.py", line 238, in _resolve_classes
#
#     warn(f"{klass} is not importable. Is it installed?", ImportWarning)
#
# TypeError: warn() missing 1 required keyword-only argument: 'stacklevel'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
